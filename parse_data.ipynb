# %%
import pandas as pd
# Read Excel file
df = pd.read_excel('data/WID_SummaryTable_24May2019.xlsx')
print(df)
# Out:
#           Country Country Code  \
# 0     Afghanistan           AF
# 1     Afghanistan           AF
# 2     Afghanistan           AF
# 3     Afghanistan           AF
# 4     Afghanistan           AF
# ...           ...          ...
# 6248     Zimbabwe           ZW
# 6249     Zimbabwe           ZW
# 6250     Zimbabwe           ZW
# 6251     Zimbabwe           ZW
# 6252     Zimbabwe           ZW
#
#                                 Short name of variable  \
# 0                                      National income
# 1                                 Net domestic product
# 2     Consumption of fixed capital of national economy
# 3                               Gross domestic product
# 4                                   Net foreign income
# ...                                                ...
# 6248                 Market exchange rate, LCU per EUR
# 6249                PPP conversion factor, LCU per USD
# 6250                 Market exchange rate, LCU per USD
# ...
